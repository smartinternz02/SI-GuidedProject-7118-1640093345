# %% [markdown]
# # Assignment_2

# %% [markdown]
# ### 1. import the library and load the dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = sns.load_dataset("titanic")

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male   NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
data.shape
# Out:
# (891, 15)

# %% [markdown]
# ### 2. Deal with Missing values, Outliers and remove unwanted columns

# %%
data.isnull().any()
# Out:
# survived       False
# pclass         False
# sex            False
# age             True
# sibsp          False
# parch          False
# fare           False
# embarked        True
# class          False
# who            False
# adult_male     False
# deck            True
# embark_town     True
# alive          False
# alone          False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# # drop

# %%
data.drop(61, axis = 0, inplace = True )

# %%
data.drop(829, axis = 0, inplace = True )

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      0
# alive            0
# alone            0
# dtype: int64

# %%
data.drop("deck",axis =1,inplace =True)

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# embark_town      0
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ### fill

# %%
np.set_printoptions
# Out:
# <function numpy.set_printoptions(precision=None, threshold=None, edgeitems=None, linewidth=None, suppress=None, nanstr=None, infstr=None, formatter=None, sign=None, floatmode=None, **kwarg)>

# %%
data.mean()["age"]
# Out:
# 29.64209269662921

# %%
data.median()["age"]
# Out:
# 28.0

# %%
data["age"].mode()[0]
# Out:
# 24.0

# %%
data.fillna(data.median(), inplace = True)

# %%
data.isnull().any()
# Out:
# survived       False
# pclass         False
# sex            False
# age            False
# sibsp          False
# parch          False
# fare           False
# embarked       False
# class          False
# who            False
# adult_male     False
# embark_town    False
# alive          False
# alone          False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male   NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %% [markdown]
# #### outliers

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  889.000000  889.000000  889.000000  889.000000  889.000000  889.000000
# mean     0.382452    2.311586   29.315152    0.524184    0.382452   32.096681
# std      0.486260    0.834700   12.984932    1.103705    0.806761   49.697504
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data["age"].describe()
# Out:
# count    889.000000
# mean      29.315152
# std       12.984932
# min        0.420000
# 25%       22.000000
# 50%       28.000000
# 75%       35.000000
# max       80.000000
# Name: age, dtype: float64

# %%
q1=data["age"].describe()["25%"]

# %%
q1
# Out:
# 22.0

# %%
q3=data["age"].describe()["75%"]

# %%
q3
# Out:
# 35.0

# %%
iqr_age=q3-q1

# %%
iqr_age
# Out:
# 13.0

# %%
sns.boxplot(data["age"])

# %%
lower_boundary=q1-(1.5*iqr_age)

# %%
lower_boundary
# Out:
# 2.5

# %%
upper_boundary=q3+(1.5*iqr_age)

# %%
upper_boundary
# Out:
# 54.5

# %%
data[data["age"]<lower_boundary]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 7           0       3    male  2.00      3      1   21.0750        S   Third
# 16          0       3    male  2.00      4      1   29.1250        Q   Third
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 119         0       3  female  2.00      4      2   31.2750        S   Third
# 164         0       3    male  1.00      4      1   39.6875        S   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 183         1       2    male  1.00      2      1   39.0000        S  Second
# 205         0       3  female  2.00      0      1   10.4625        S   Third
# 297         0       1  female  2.00      1      2  151.5500        S   First
# 305         1       1    male  0.92      1      2  151.5500        S   First
# 340         1       2    male  2.00      1      1   26.0000        S  Second
# ...

# %%
data[data["age"]>upper_boundary]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 11          1       1  female  58.0      0      0   26.5500        S   First
# 15          1       2  female  55.0      0      0   16.0000        S  Second
# 33          0       2    male  66.0      0      0   10.5000        S  Second
# 54          0       1    male  65.0      0      1   61.9792        C   First
# 94          0       3    male  59.0      0      0    7.2500        S   Third
# 96          0       1    male  71.0      0      0   34.6542        C   First
# 116         0       3    male  70.5      0      0    7.7500        Q   Third
# 152         0       3    male  55.5      0      0    8.0500        S   Third
# 170         0       1    male  61.0      0      0   33.5000        S   First
# 174         0       1    male  56.0      0      0   30.6958        C   First
# 195         1       1  female  58.0      0      0  146.5208        C   First
# ...

# %%
(data[data["age"]>upper_boundary].shape[0]/data["age"].shape[0])*100
# Out:
# 4.611923509561304

# %%
(data[data["age"]<lower_boundary].shape[0]/data["age"].shape[0])*100
# Out:
# 2.699662542182227

# %% [markdown]
# #### fare

# %%
data["fare"].describe()
# Out:
# count    889.000000
# mean      32.096681
# std       49.697504
# min        0.000000
# 25%        7.895800
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
q1=data["fare"].describe()["25%"]

# %%
q1
# Out:
# 7.8958

# %%
q3=data["fare"].describe()["75%"]

# %%
q3
# Out:
# 31.0

# %%
iqr_fare=q3-q1

# %%
iqr_fare
# Out:
# 23.1042

# %%
sns.boxplot(data["fare"])

# %%
lower_boundary=q1-(1.5*iqr_fare)

# %%
lower_boundary
# Out:
# -26.7605

# %%
upper_boundary=q3+(1.5*iqr_fare)

# %%
upper_boundary
# Out:
# 65.6563

# %%
data[data["fare"]<lower_boundary]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, embark_town, alive, alone]
# Index: []

# %%
data[data["fare"]>upper_boundary]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male   NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
(data[data["fare"]>upper_boundary].shape[0]/data["fare"].shape[0])*100
# Out:
# 12.823397075365579

# %%
##it is greater than 5%. there is no elimination

# %% [markdown]
# #### sibsp

# %%
data["sibsp"].describe()
# Out:
# count    889.000000
# mean       0.524184
# std        1.103705
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        8.000000
# Name: sibsp, dtype: float64

# %%
q1=data["sibsp"].describe()["25%"]

# %%
q1
# Out:
# 0.0

# %%
q3=data["sibsp"].describe()["75%"]

# %%
q3
# Out:
# 1.0

# %%
iqr_sib=q3-q1

# %%
iqr_sib
# Out:
# 1.0

# %%
sns.boxplot(data["sibsp"])

# %%
lower_boundary=q1-(1.5*iqr_sib)

# %%
lower_boundary
# Out:
# -1.5

# %%
upper_boundary=q3+(1.5*iqr_sib)

# %%
upper_boundary
# Out:
# 2.5

# %%
data[data["sibsp"]<lower_boundary]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, embark_town, alive, alone]
# Index: []

# %%
data[data["fare"]>upper_boundary]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male  28.0      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
(data[data["sibsp"]>upper_boundary].shape[0]/data["sibsp"].shape[0])*100
# Out:
# 5.174353205849269

# %% [markdown]
# #### parch

# %%
data["parch"].describe()
# Out:
# count    889.000000
# mean       0.382452
# std        0.806761
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        6.000000
# Name: parch, dtype: float64

# %%
q1=data["parch"].describe()["25%"]

# %%
q1
# Out:
# 0.0

# %%
q3=data["parch"].describe()["75%"]

# %%
q3
# Out:
# 0.0

# %%
iqr_parch=q3-q1

# %%
iqr_parch
# Out:
# 0.0

# %%
sns.boxplot(data["parch"])

# %%
lower_boundary=q1-(1.5*iqr_parch)

# %%
lower_boundary
# Out:
# 0.0

# %%
upper_boundary=q3+(1.5*iqr_parch)

# %%
upper_boundary
# Out:
# 0.0

# %%
data[data["parch"]<lower_boundary]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, embark_town, alive, alone]
# Index: []

# %%
data[data["parch"]>upper_boundary]
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 7           0       3    male   2.00      3      1   21.0750        S   Third
# 8           1       3  female  27.00      0      2   11.1333        S   Third
# 10          1       3  female   4.00      1      1   16.7000        S   Third
# 13          0       3    male  39.00      1      5   31.2750        S   Third
# 16          0       3    male   2.00      4      1   29.1250        Q   Third
# 24          0       3  female   8.00      3      1   21.0750        S   Third
# 25          1       3  female  38.00      1      5   31.3875        S   Third
# 27          0       1    male  19.00      3      2  263.0000        S   First
# 43          1       2  female   3.00      1      2   41.5792        C  Second
# 50          0       3    male   7.00      4      1   39.6875        S   Third
# 54          0       1    male  65.00      0      1   61.9792        C   First
# ...

# %%
(data[data["parch"]>upper_boundary].shape[0]/data["parch"].shape[0])*100
# Out:
# 23.95950506186727

# %%
##here outliers are greater than 3% we cannot eliminate it .

# %% [markdown]
# ## 3.Perform exploratory Data analysis
#   ## a.Perform Descriptive statistics
#   ## b.Do Data visualisation using seaborn and matplotlib(10-15 visualizations)

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male  28.0      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  889.000000  889.000000  889.000000  889.000000  889.000000  889.000000
# mean     0.382452    2.311586   29.315152    0.524184    0.382452   32.096681
# std      0.486260    0.834700   12.984932    1.103705    0.806761   49.697504
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ##### mean

# %%
data.mean()["age"]
# Out:
# 29.64209269662921

# %% [markdown]
# ###### median

# %%
data.median()["age"]
# Out:
# 28.0

# %% [markdown]
# ###### mode

# %%
data["age"].mode()[0]
# Out:
# 24.0

# %% [markdown]
# ###### varience

# %%
data["age"].var()
# Out:
# 210.04510405327994

# %% [markdown]
# ###### standard deviation

# %%
data["age"].std()
# Out:
# 14.49293290032352

# %% [markdown]
# ###### length

# %%
len(data)
# Out:
# 889

# %% [markdown]
# ###### visualisations

# %% [markdown]
# ###### 1.

# %%
a=data["embark_town"].value_counts()

# %%
a
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
a.index
# Out:
# Index(['Southampton', 'Cherbourg', 'Queenstown'], dtype='object')

# %%
a.values
# Out:
# array([644, 168,  77], dtype=int64)

# %%
plt.bar(a.index,a.values,color=["red","green","blue"])
plt.xlabel("embark_town")
plt.ylabel("frequency")
plt.title("count of the people from each town")
plt.show()

# %% [markdown]
# ##### obsevation

# %% [markdown]
# ###### most of the passengers are from southampton town

# %% [markdown]
# ###### least are from  queenstown
#
#
# remaining passengers are from cherbourg

# %% [markdown]
# ##### 2.

# %%
e=data["sex"].value_counts()

# %%
e
# Out:
# male      577
# female    312
# Name: sex, dtype: int64

# %%
e.values
# Out:
# array([577, 312], dtype=int64)

# %%
e.index
# Out:
# Index(['male', 'female'], dtype='object')

# %%
len(e.sort_values(ascending=False))
# Out:
# 2

# %%
explode = np.zeros(len(e))

# %%
explode
# Out:
# array([0., 0.])

# %%
e= e.sample(frac = 1)

# %%
e
# Out:
# female    312
# male      577
# Name: sex, dtype: int64

# %%
plt.pie(e.values, labels = e.index, autopct = "%.1f %%", colors = ["#008E98", "#10DFEE"], 
        explode = explode, pctdistance=0.7)
plt.show()

# %% [markdown]
# ###### observations

# %% [markdown]
# ###### in Titanic,there are 64.9% male passengers and 35.1% of female passengers.its shows male passengers are more in number .

# %% [markdown]
# #### 3.

# %%
b=data["who"].value_counts()

# %%
b
# Out:
# man      537
# woman    269
# child     83
# Name: who, dtype: int64

# %%
b.index
# Out:
# Index(['man', 'woman', 'child'], dtype='object')

# %%
b.values
# Out:
# array([537, 269,  83], dtype=int64)

# %%
plt.bar(b.index,b.values,color=["red","green","blue"])
plt.xlabel("categories")
plt.ylabel("frequency")
plt.title("count of passengers")
plt.show()

# %% [markdown]
# ###### obsevations

# %% [markdown]
# ###### most of the passengers are men

# %% [markdown]
# ###### number of women are in between 200 and 300

# %% [markdown]
# ###### least number of travellers are children

# %% [markdown]
# ##### 4.

# %%
e=data["survived"].value_counts()

# %%
e
# Out:
# 0    549
# 1    340
# Name: survived, dtype: int64

# %%
e.index
# Out:
# Int64Index([0, 1], dtype='int64')

# %%
e.values
# Out:
# array([549, 340], dtype=int64)

# %%
plt.bar(e.index,e.values,color=["red","green"])
plt.xlabel("survived")
plt.ylabel("count")
plt.title("number of people are survived")
plt.show()

# %% [markdown]
# ###### observations

# %% [markdown]
# ###### 340 people are survived and 549 people are not survived

# %% [markdown]
# ###### 5.

# %%
f=data["class"].value_counts()

# %%
f
# Out:
# Third     491
# First     214
# Second    184
# Name: class, dtype: int64

# %%
f.values
# Out:
# array([491, 214, 184], dtype=int64)

# %%
f.index
# Out:
# CategoricalIndex(['Third', 'First', 'Second'], categories=['First', 'Second', 'Third'], ordered=False, dtype='category')

# %%
len(f.sort_values(ascending=False))
# Out:
# 3

# %%
explode = np.zeros(len(f))

# %%
explode
# Out:
# array([0., 0., 0.])

# %%
f= f.sample(frac = 1)

# %%
f
# Out:
# Second    184
# Third     491
# First     214
# Name: class, dtype: int64

# %%
plt.pie(f.values, labels = f.index, autopct = "%.1f %%", colors = ["red", "green", "blue"], 
        explode = explode, pctdistance=0.7)
plt.show()

# %% [markdown]
# ###### observations

# %% [markdown]
# ###### most of the passengers are travelled in  third class,they are poor.Least is  in second class and  remaining 24.15% of passengers  are first class

# %% [markdown]
# ###### 6.

# %%
sns.barplot(data=data,x='pclass',y='survived')
plt.xlabel("passengerclass")
plt.ylabel("survived")
plt.title("count of survived people based on pclass")
plt.show()

# %% [markdown]
# ###### observations

# %% [markdown]
# ###### most of the 1st class passengers are survived when we combared to others.

# %% [markdown]
# ###### 3rd class passengers are less survived

# %% [markdown]
# ###### 7.

# %%
sns.barplot(data=data,x='who',y='survived')
plt.xlabel(" categories of people ")
plt.ylabel("survived")
plt.title("count of survived people ")
plt.show()

# %% [markdown]
# ##### obsevations

# %% [markdown]
# ###### mainly women are survived when we compared to others.they give more priority

# %% [markdown]
# ###### childrens also get more consideration

# %% [markdown]
# ###### least survived passengers are men

# %% [markdown]
# ###### 8.

# %%
plt.scatter(data=data,x='class',y='fare')
plt.xlabel("  categories of ticket ")
plt.ylabel(" fare ")
plt.title("  cost of ticket  ")
plt.show()

# %% [markdown]
# ###### obsevations
# first class ticket have high cost
#  , third and second class ticket has less fare

# %% [markdown]
# ###### 9.

# %%
sns.barplot(data=data,x='embark_town',y='survived')
plt.xlabel("embark_town")
plt.ylabel("survived")
plt.title("count of survived people based on town")
plt.show()

# %% [markdown]
# ###### observations
# majority of passengers are boarded from s .
#
#
# passengers from cherbourg are mostly survived passengers

# %% [markdown]
# ###### 10.

# %%
sns.barplot(data=data,x='embark_town',y='fare')
plt.xlabel("embark_town")
plt.ylabel("fair")
plt.title("cost of ticket  based on town")
plt.show()

# %% [markdown]
# ###### observations
# passengers from cherbourg  spent more money for fare
#
#
# it shows who paid a higher fare,the survival rate is more

# %% [markdown]
# ###### 11.

# %%
sns.violinplot(x="sex" , y="age" ,hue="survived", data=data, split= True)

# %% [markdown]
# ###### observations
# the survival rate is high for women in the age range 20_40
#
#
# survival rate is less for men as the age increases

# %% [markdown]
# ###### 12.

# %%
sns.factorplot(x='alone',y='survived',data=data)

# %% [markdown]
# ###### observations
# if passsenger is alone,the survival rate is less

# %% [markdown]
# ###### 13.

# %%
sns.factorplot(x='sibsp',y='survived',data=data)

# %% [markdown]
# ###### observations
# if family size is greater then survival is decreases considerably
